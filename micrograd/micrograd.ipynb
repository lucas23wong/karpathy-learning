# %% [markdown]
# ### The Spelled-Out intro to neural networks and backpropagation: building micrograd

# %%
class Value: 

    def __init__(self, data, _children=(), _op=''): 
        self.data = data 
        self.prev = set(_children)
    
    def __repr__(self): 
        return f"Value(data={self.data}"

    def __add__(self, other): 
        out = Value(self.data + other.data, (self, other), '+')
        return out
    
    def __mul__(self, other): 
        out = Value(self.data * other.data, (self, other), '*')
        return out

# %%
a = Value(3.0)
b = Value(-2.0)
c = Value(10.0)

d = a * b + c
d
# Out:
# Value(data=4.0

# %%
from graphviz import Digraph

def trace(root):
    # builds a set of all nodes and edges in the graph
    nodes, edges = set(), set()
    def build(v):
        if v not in nodes:
            nodes.add(v)
            for child in v.prev:
                edges.add((child, v))
                build(child)
    build(root)
    return nodes, edges

def draw_dot(root):
    dot = Digraph(format='svg', graph_attr={'rankdir': 'LR'}) # LR = left to right
    
    nodes, edges = trace(root)
    for n in nodes:
        uid = str(id(n))
        # for any value in the graph, create a rectangular node
        dot.node(name=uid, label="{ %s | data %.4f }" % (n.label, n.data), shape='record')
        if n._op:
            # if this value is a result of an operation, create an op node
            dot.node(name=uid + n._op, label=n._op)
            # and connect this node to it
            dot.edge(uid + n._op, uid)
    
    for n1, n2 in edges:
        # connect n1 to the op node of n2
        dot.edge(str(id(n1)), str(id(n2)) + n2._op)
    
    return dot

# %%
draw_dot(d)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/lucaswong/Developer/karpathy-learning/micrograd/micrograd.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/Users/lucaswong/Developer/karpathy-learning/micrograd/micrograd.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> draw_dot(d)
#
# /Users/lucaswong/Developer/karpathy-learning/micrograd/micrograd.ipynb Cell 5 line 2
#      <a href='vscode-notebook-cell:/Users/lucaswong/Developer/karpathy-learning/micrograd/micrograd.ipynb#W6sZmlsZQ%3D%3D?line=19'>20</a> uid = str(id(n))
#      <a href='vscode-notebook-cell:/Users/lucaswong/Developer/karpathy-learning/micrograd/micrograd.ipynb#W6sZmlsZQ%3D%3D?line=20'>21</a> # for any value in the graph, create a rectangular node
# ---> <a href='vscode-notebook-cell:/Users/lucaswong/Developer/karpathy-learning/micrograd/micrograd.ipynb#W6sZmlsZQ%3D%3D?line=21'>22</a> dot.node(name=uid, label="{ %s | data %.4f }" % (n.label, n.data), shape='record')
#      <a href='vscode-notebook-cell:/Users/lucaswong/Developer/karpathy-learning/micrograd/micrograd.ipynb#W6sZmlsZQ%3D%3D?line=22'>23</a> if n._op:
#      <a href='vscode-notebook-cell:/Users/lucaswong/Developer/karpathy-learning/micrograd/micrograd.ipynb#W6sZmlsZQ%3D%3D?line=23'>24</a>     # if this value is a result of an operation, create an op node
#      <a href='vscode-notebook-cell:/Users/lucaswong/Developer/karpathy-learning/micrograd/micrograd.ipynb#W6sZmlsZQ%3D%3D?line=24'>25</a>     dot.node(name=uid + n._op, label=n._op)
#
# AttributeError: 'Value' object has no attribute 'label'
